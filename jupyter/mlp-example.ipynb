# %%
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
from torch.utils.data import Dataset, random_split, DataLoader, Subset
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import accuracy_score, classification_report
from tqdm import tqdm
import random
import numpy as np
import os
import joblib

# %%
class Preprocessing:
    def __init__(self, is_train=True):
        self.transformer = dict()
        self.is_train = is_train
        if not self.is_train:
            self.transformer = self.load()

    def __call__(self, df, is_timeseries=False):
        if self.is_train:
            return self.fit_transform(df)
        else:
            return self.transform(df)

    def fit_transform(self, df):
        for column in df.columns:
            if 'cpu-util' in column:
                self.transformer[column] = MinMaxScaler()
            else:
                self.transformer[column] = StandardScaler()
            value = self.transformer[column].fit_transform(pd.DataFrame(df[column]))
            df.loc[:, column] = value
        return df

    def transform(self, df):
        for column in df.columns:
            value = self.transformer[column].transform(
                pd.DataFrame(df[column]))
            df.loc[:, column] = value
        return df

    def dump(self, filename='/tmp/mlp_transfomer.bin'):
        with open(filename, 'wb') as f:
            joblib.dump(self.transformer, f)

    def load(self, filename='/tmp/mlp_transfomer.bin'):
        with open(filename, 'rb') as f:
            data = joblib.load(f)
        return data

# %%
class NetworkMetricsDataset(Dataset):
    def __init__(self, path, metrics, device, transformer=None):
        self.path = path
        self.metrics = metrics
        self.device = device
        self.transformer = transformer
        
        data = []
        for metric in tqdm(self.metrics):
            df = pd.read_csv(os.path.join(self.path, metric + '.tsv'), sep="\t", index_col=0)
            df = df.fillna(0)
            df = df.sort_values("timestamp")
            df = df.set_index("timestamp")
            columns = {name: metric + '-' + name for name in df.columns}
            df.rename(columns=columns, inplace=True)
            if self.transformer:
                df = self.transformer(df)
            data.append(df)
        self.dataframe = pd.concat(data, axis=1)
        self.data = self.dataframe.values
        self.data_size = len(self.dataframe)
        self.labels = pd.read_csv(os.path.join(self.path, 'label.tsv'), sep="\t", index_col=0).set_index("timestamp").values
        
    def __len__(self):
        return self.data_size
    
    def __getitem__(self, idx):
        ret = self.data[idx]
        ret = torch.tensor(ret, dtype=torch.float, device=self.device)
        label = self.labels[idx]
        label = torch.tensor(label, dtype=torch.float, device=self.device)
        
        return ret, label

# %%
class MLPClassifier(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(MLPClassifier, self).__init__()
        self.input_dim = input_dim
        self.output_dim = output_dim
        hidden_dim = 128
        self.mlp = nn.Sequential(
            nn.Linear(self.input_dim, hidden_dim),
            nn.ReLU(),
            nn.Dropout(p=0.2),
            nn.Linear(hidden_dim, self.output_dim),
#             nn.Softmax(dim=1), # loss functionにsoftmaxが組み込まれているため不要
        )

    def forward(self, x):
        return self.mlp(x)

# %%
device = 'cpu'
path = "../dataset/train"
metrics = ["cpu-util", "tx-pps", "rx-pps", "network-incoming-packets-rate", "network-outgoing-packets-rate", "prefix-activity-received-current-prefixes"]
events = {
    'normal': 0,
    'ixnetwork-bgp-hijacking-start': 1,
    'ixnetwork-bgp-injection-start': 2,
    'node-down': 3,
    'interface-down': 4,
    'packet-loss-delay': 5,
}
seed = 1
torch.manual_seed(seed)
random.seed(seed)
np.random.seed(seed)

batchsize = 16
max_epoch = 100
model_dir = "models/mlp"
os.makedirs(model_dir, exist_ok=True)
transformer = Preprocessing(is_train=True)
dataset = NetworkMetricsDataset(path, metrics, device, transformer)
transformer.dump()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 18.01it/s]

# %%
train_indices, val_indices = train_test_split(
    list(range(len(dataset))),
    test_size=0.2,
    stratify=dataset.labels,
    random_state=seed,
)
train_dataset = Subset(dataset, train_indices)
train_size = len(train_dataset)
val_dataset = Subset(dataset, val_indices)
val_size = len(val_dataset)
print(f'train size : {train_size} val size: {val_size}')
train_dataloader = DataLoader(train_dataset, batch_size=batchsize)
val_dataloader = DataLoader(val_dataset, batch_size=val_size)

val_data, val_labels = iter(val_dataloader).next()
val_data = val_data.float().to(device)
val_labels = val_labels.long().to(device).view(-1)
# Out:
# train size : 4775 val size: 1194

# %%
input_dim = list(train_dataset[0][0].shape)[-1]
output_dim = len(events.keys())
model = MLPClassifier(input_dim, output_dim).to(device)
loss_function = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# %%
for epoch in range(1, max_epoch+1):
    running_loss = 0
    correct = 0
    total = 0
    model = model.train()
    # Training
    for train_data, train_labels in train_dataloader:
        train_data = train_data.float().to(device)
        train_labels = train_labels.long().to(device).view(-1)
        
        model.zero_grad()
        train_scores = model(train_data)
        loss = loss_function(train_scores, train_labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predict = torch.max(train_scores.data, 1)
        correct += (predict == train_labels).sum().item()
        total += train_labels.size(0)

    train_loss = running_loss / len(train_dataloader)
    train_acc = correct / total

    # Check model validation 
    model = model.eval()
    with torch.no_grad():
        val_scores = model(val_data)
        val_loss = loss_function(val_scores, val_labels)

        bi_scores = torch.argmax(val_scores, dim=1).to(device).numpy()
        y_val_scores = val_labels.to(device).numpy()
        val_acc = accuracy_score(y_val_scores, bi_scores)
    
    print(f'EPOCH: [{epoch}/{max_epoch}] train loss: {train_loss:.4f} train acc: {train_acc:.4f} val loss: {val_loss:.4f} val acc: {val_acc:4f}')
    # Export model
    if epoch % 10 == 0:
        torch.save(model.state_dict(), f"./{model_dir}/mlp_{epoch}.mdl")
# Out:
# EPOCH: [1/100] train loss: 0.7817 train acc: 0.7516 val loss: 0.6498 val acc: 0.793132
# EPOCH: [2/100] train loss: 0.6390 train acc: 0.8132 val loss: 0.6022 val acc: 0.818258
# EPOCH: [3/100] train loss: 0.6041 train acc: 0.8237 val loss: 0.5756 val acc: 0.825796
# EPOCH: [4/100] train loss: 0.5733 train acc: 0.8329 val loss: 0.5453 val acc: 0.839196
# EPOCH: [5/100] train loss: 0.5538 train acc: 0.8392 val loss: 0.5352 val acc: 0.831658
# EPOCH: [6/100] train loss: 0.5356 train acc: 0.8448 val loss: 0.5095 val acc: 0.841709
# EPOCH: [7/100] train loss: 0.5142 train acc: 0.8494 val loss: 0.4941 val acc: 0.850921
# EPOCH: [8/100] train loss: 0.4998 train acc: 0.8540 val loss: 0.4866 val acc: 0.852596
# EPOCH: [9/100] train loss: 0.4931 train acc: 0.8565 val loss: 0.4812 val acc: 0.849246
# EPOCH: [10/100] train loss: 0.4844 train acc: 0.8576 val loss: 0.4767 val acc: 0.849246
# EPOCH: [11/100] train loss: 0.4806 train acc: 0.8565 val loss: 0.4747 val acc: 0.850084
# EPOCH: [12/100] train loss: 0.4700 train acc: 0.8593 val loss: 0.4574 val acc: 0.855946
# EPOCH: [13/100] train loss: 0.4652 train acc: 0.8620 val loss: 0.4601 val acc: 0.852596
# EPOCH: [14/100] train loss: 0.4556 train acc: 0.8643 val loss: 0.4523 val acc: 0.857621
# EPOCH: [15/100] train loss: 0.4574 train acc: 0.8647 val loss: 0.4593 val acc: 0.856784
# EPOCH: [16/100] train loss: 0.4487 train acc: 0.8660 val loss: 0.4499 val acc: 0.860972
# EPOCH: [17/100] train loss: 0.4532 train acc: 0.8635 val loss: 0.4379 val acc: 0.865997
# EPOCH: [18/100] train loss: 0.4394 train acc: 0.8676 val loss: 0.4363 val acc: 0.867672
# EPOCH: [19/100] train loss: 0.4350 train acc: 0.8683 val loss: 0.4354 val acc: 0.867672
# EPOCH: [20/100] train loss: 0.4305 train acc: 0.8695 val loss: 0.4334 val acc: 0.866834
# EPOCH: [21/100] train loss: 0.4323 train acc: 0.8683 val loss: 0.4244 val acc: 0.867672
# EPOCH: [22/100] train loss: 0.4315 train acc: 0.8685 val loss: 0.4322 val acc: 0.868509
# EPOCH: [23/100] train loss: 0.4269 train acc: 0.8681 val loss: 0.4304 val acc: 0.869347
# EPOCH: [24/100] train loss: 0.4254 train acc: 0.8714 val loss: 0.4214 val acc: 0.870184
# EPOCH: [25/100] train loss: 0.4231 train acc: 0.8702 val loss: 0.4247 val acc: 0.874372
# EPOCH: [26/100] train loss: 0.4179 train acc: 0.8729 val loss: 0.4254 val acc: 0.871022
# EPOCH: [27/100] train loss: 0.4165 train acc: 0.8720 val loss: 0.4193 val acc: 0.871859
# EPOCH: [28/100] train loss: 0.4149 train acc: 0.8729 val loss: 0.4271 val acc: 0.870184
# EPOCH: [29/100] train loss: 0.4150 train acc: 0.8716 val loss: 0.4273 val acc: 0.873534
# EPOCH: [30/100] train loss: 0.4125 train acc: 0.8741 val loss: 0.4239 val acc: 0.871859
# EPOCH: [31/100] train loss: 0.4112 train acc: 0.8741 val loss: 0.4172 val acc: 0.871859
# EPOCH: [32/100] train loss: 0.4104 train acc: 0.8737 val loss: 0.4215 val acc: 0.871859
# EPOCH: [33/100] train loss: 0.4076 train acc: 0.8754 val loss: 0.4204 val acc: 0.872697
# EPOCH: [34/100] train loss: 0.4079 train acc: 0.8752 val loss: 0.4165 val acc: 0.874372
# EPOCH: [35/100] train loss: 0.4057 train acc: 0.8750 val loss: 0.4416 val acc: 0.864322
# EPOCH: [36/100] train loss: 0.4081 train acc: 0.8746 val loss: 0.4214 val acc: 0.874372
# EPOCH: [37/100] train loss: 0.4029 train acc: 0.8756 val loss: 0.4200 val acc: 0.871859
# EPOCH: [38/100] train loss: 0.3955 train acc: 0.8758 val loss: 0.4169 val acc: 0.873534
# EPOCH: [39/100] train loss: 0.3942 train acc: 0.8777 val loss: 0.4182 val acc: 0.874372
# EPOCH: [40/100] train loss: 0.3991 train acc: 0.8758 val loss: 0.4180 val acc: 0.872697
# EPOCH: [41/100] train loss: 0.3952 train acc: 0.8769 val loss: 0.4188 val acc: 0.872697
# EPOCH: [42/100] train loss: 0.3926 train acc: 0.8781 val loss: 0.4146 val acc: 0.875209
# EPOCH: [43/100] train loss: 0.4001 train acc: 0.8762 val loss: 0.4151 val acc: 0.873534
# EPOCH: [44/100] train loss: 0.3954 train acc: 0.8775 val loss: 0.4326 val acc: 0.872697
# EPOCH: [45/100] train loss: 0.4012 train acc: 0.8758 val loss: 0.4420 val acc: 0.872697
# EPOCH: [46/100] train loss: 0.3927 train acc: 0.8773 val loss: 0.4253 val acc: 0.874372
# EPOCH: [47/100] train loss: 0.3926 train acc: 0.8779 val loss: 0.4205 val acc: 0.876884
# EPOCH: [48/100] train loss: 0.3901 train acc: 0.8775 val loss: 0.4403 val acc: 0.873534
# EPOCH: [49/100] train loss: 0.3965 train acc: 0.8779 val loss: 0.4353 val acc: 0.870184
# EPOCH: [50/100] train loss: 0.3932 train acc: 0.8766 val loss: 0.4216 val acc: 0.876047
# EPOCH: [51/100] train loss: 0.3914 train acc: 0.8783 val loss: 0.4231 val acc: 0.877722
# EPOCH: [52/100] train loss: 0.3856 train acc: 0.8785 val loss: 0.4309 val acc: 0.876884
# EPOCH: [53/100] train loss: 0.3951 train acc: 0.8783 val loss: 0.4235 val acc: 0.877722
# EPOCH: [54/100] train loss: 0.3834 train acc: 0.8800 val loss: 0.4316 val acc: 0.876047
# EPOCH: [55/100] train loss: 0.3875 train acc: 0.8800 val loss: 0.4170 val acc: 0.877722
# EPOCH: [56/100] train loss: 0.3896 train acc: 0.8798 val loss: 0.4304 val acc: 0.876884
# EPOCH: [57/100] train loss: 0.3818 train acc: 0.8800 val loss: 0.4345 val acc: 0.876047
# EPOCH: [58/100] train loss: 0.3873 train acc: 0.8792 val loss: 0.4328 val acc: 0.876047
# EPOCH: [59/100] train loss: 0.3824 train acc: 0.8796 val loss: 0.4326 val acc: 0.873534
# EPOCH: [60/100] train loss: 0.3848 train acc: 0.8785 val loss: 0.4296 val acc: 0.876884
# EPOCH: [61/100] train loss: 0.3848 train acc: 0.8790 val loss: 0.4320 val acc: 0.877722
# EPOCH: [62/100] train loss: 0.3794 train acc: 0.8810 val loss: 0.4340 val acc: 0.872697
# EPOCH: [63/100] train loss: 0.3776 train acc: 0.8798 val loss: 0.4321 val acc: 0.877722
# EPOCH: [64/100] train loss: 0.3774 train acc: 0.8802 val loss: 0.4265 val acc: 0.876884
# EPOCH: [65/100] train loss: 0.3752 train acc: 0.8802 val loss: 0.4375 val acc: 0.876884
# EPOCH: [66/100] train loss: 0.3769 train acc: 0.8798 val loss: 0.4280 val acc: 0.876884
# EPOCH: [67/100] train loss: 0.3735 train acc: 0.8819 val loss: 0.4266 val acc: 0.876047
# EPOCH: [68/100] train loss: 0.3713 train acc: 0.8815 val loss: 0.4444 val acc: 0.875209
# EPOCH: [69/100] train loss: 0.3767 train acc: 0.8800 val loss: 0.4358 val acc: 0.875209
# EPOCH: [70/100] train loss: 0.3688 train acc: 0.8825 val loss: 0.4342 val acc: 0.877722
# EPOCH: [71/100] train loss: 0.3691 train acc: 0.8823 val loss: 0.4350 val acc: 0.876884
# EPOCH: [72/100] train loss: 0.3763 train acc: 0.8808 val loss: 0.4370 val acc: 0.876884
# EPOCH: [73/100] train loss: 0.3692 train acc: 0.8813 val loss: 0.4465 val acc: 0.876047
# EPOCH: [74/100] train loss: 0.3720 train acc: 0.8802 val loss: 0.4471 val acc: 0.877722
# EPOCH: [75/100] train loss: 0.3732 train acc: 0.8813 val loss: 0.4399 val acc: 0.877722
# EPOCH: [76/100] train loss: 0.3811 train acc: 0.8794 val loss: 0.4317 val acc: 0.876047
# EPOCH: [77/100] train loss: 0.3722 train acc: 0.8802 val loss: 0.4461 val acc: 0.874372
# EPOCH: [78/100] train loss: 0.3660 train acc: 0.8819 val loss: 0.4411 val acc: 0.877722
# EPOCH: [79/100] train loss: 0.3708 train acc: 0.8817 val loss: 0.4344 val acc: 0.876047
# EPOCH: [80/100] train loss: 0.3647 train acc: 0.8810 val loss: 0.4340 val acc: 0.876884
# EPOCH: [81/100] train loss: 0.3692 train acc: 0.8808 val loss: 0.4616 val acc: 0.875209
# EPOCH: [82/100] train loss: 0.3638 train acc: 0.8829 val loss: 0.4652 val acc: 0.875209
# EPOCH: [83/100] train loss: 0.3625 train acc: 0.8829 val loss: 0.4633 val acc: 0.873534
# EPOCH: [84/100] train loss: 0.3670 train acc: 0.8817 val loss: 0.4417 val acc: 0.874372
# EPOCH: [85/100] train loss: 0.3618 train acc: 0.8838 val loss: 0.4529 val acc: 0.876047
# EPOCH: [86/100] train loss: 0.3645 train acc: 0.8819 val loss: 0.4575 val acc: 0.875209
# EPOCH: [87/100] train loss: 0.3542 train acc: 0.8838 val loss: 0.4668 val acc: 0.874372
# EPOCH: [88/100] train loss: 0.3651 train acc: 0.8815 val loss: 0.4605 val acc: 0.876047
# EPOCH: [89/100] train loss: 0.3743 train acc: 0.8808 val loss: 0.4633 val acc: 0.875209
# EPOCH: [90/100] train loss: 0.3566 train acc: 0.8836 val loss: 0.4608 val acc: 0.874372
# EPOCH: [91/100] train loss: 0.3601 train acc: 0.8806 val loss: 0.4674 val acc: 0.876047
# EPOCH: [92/100] train loss: 0.3580 train acc: 0.8836 val loss: 0.4695 val acc: 0.876047
# EPOCH: [93/100] train loss: 0.3581 train acc: 0.8831 val loss: 0.4701 val acc: 0.875209
# EPOCH: [94/100] train loss: 0.3581 train acc: 0.8842 val loss: 0.4640 val acc: 0.877722
# EPOCH: [95/100] train loss: 0.3497 train acc: 0.8861 val loss: 0.4596 val acc: 0.877722
# EPOCH: [96/100] train loss: 0.3593 train acc: 0.8821 val loss: 0.4626 val acc: 0.877722
# EPOCH: [97/100] train loss: 0.3493 train acc: 0.8865 val loss: 0.4684 val acc: 0.876884
# EPOCH: [98/100] train loss: 0.3543 train acc: 0.8850 val loss: 0.4747 val acc: 0.874372
# EPOCH: [99/100] train loss: 0.3555 train acc: 0.8840 val loss: 0.4651 val acc: 0.876047
# EPOCH: [100/100] train loss: 0.3531 train acc: 0.8842 val loss: 0.4668 val acc: 0.876047

# %%
model_path = os.path.join(model_dir, "mlp_100.mdl")
path = '../dataset/test'
transformer = Preprocessing(is_train=False)
dataset = NetworkMetricsDataset(path, metrics, device, transformer)

input_dim = list(dataset[0][0].shape)[-1]
output_dim = len(events.keys())

test_dataloader = DataLoader(dataset, batch_size=len(dataset))
test_data, test_label = iter(test_dataloader).next()
test_data = test_data.float().to(device)
test_label = test_label.long().to(device).view(-1)

model = MLPClassifier(input_dim, output_dim).to(device)
model.load_state_dict(torch.load(model_path))
model = model.eval()
loss_function = nn.CrossEntropyLoss()
with torch.no_grad():
    test_scores = model(test_data)
    loss = loss_function(test_scores, test_label)
    bi_scores = torch.argmax(test_scores, dim=1).to('cpu').numpy()
    y_test_scores = test_label.to('cpu').numpy()
print(accuracy_score(y_test_scores, bi_scores))
print(classification_report(y_test_scores, bi_scores, target_names=list(events.keys())))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 26.35it/s]
# 0.9021188824301519
#                                precision    recall  f1-score   support
#
#                        normal       0.88      0.99      0.93      3505
# ixnetwork-bgp-hijacking-start       0.99      0.71      0.82       377
# ixnetwork-bgp-injection-start       0.97      0.96      0.96       329
#                     node-down       1.00      0.94      0.97       140
#                interface-down       0.85      0.60      0.70       157
#             packet-loss-delay       0.97      0.64      0.77       825
#
#                      accuracy                           0.90      5333
#                     macro avg       0.94      0.81      0.86      5333
#                  weighted avg       0.91      0.90      0.90      5333
